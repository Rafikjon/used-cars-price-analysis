# %% [markdown]
# # Used Cars Price Analysis

# %% [markdown]
# ## This project explores used car prices in the United States using data analysis and visualization techniques with Python, Pandas, and Matplotlib.
# ## Dataset Description
# ## Outlier Analysis
# ## Price Distribution
# - `id`
# - `url`
# - `region`
# - `region_url`
# - `price`
# - `year`
# - `manufacturer`
# - `model`
# - `condition`
# - `cylinders`
# - `fuel`
# - `odometer`
# - `title_status`
# - `transmission`
# - `VIN`
# - `drive`
# - `size`
# - `type`
# - `paint_color`
# - `image_url`
# - `description`
# - `county`
# - `state`
# - `lat`
# - `long`
# - `posting_date`
# - `price_category`

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/vehicles_dataset_upd.csv')
df.head(5)
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7316474668  https://newyork.craigslist.org/lgi/cto/d/baldw...
#
#           region                           region_url  price  year  \
# 0    chattanooga   https://chattanooga.craigslist.org  54990  2020
# 1   north jersey     https://newjersey.craigslist.org  16942  2016
# 2   reno / tahoe          https://reno.craigslist.org  35590  2017
# 3   fayetteville  https://fayetteville.craigslist.org  14500  2013
# 4  new york city       https://newyork.craigslist.org  21800  2021
#
#   manufacturer                   model    fuel  odometer title_status  \
# 0          ram  2500 crew cab big horn  diesel     27442        clean
# ...

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['price'], bins=15, color='indigo')

plt.title('Car Price Distribution')
plt.xlabel('Price (USD)')
plt.ylabel('Frequency')
plt.show();

# %%
from matplotlib.ticker import FormatStrFormatter
fig, ax = plt.subplots(figsize=(5, 15))
ax.boxplot(df.price)
ax.set_ylabel('Price (USD)')
ax.set_title('Used Car Price Outlier Analysis')
ax.set_xticks([])

ax.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# %%
df.price.describe().apply(lambda x: f"{x:0.3f}")
# Out:
# count        9868.000
# mean        20602.005
# std        125437.186
# min           500.000
# 25%          7800.000
# 50%         15590.000
# 75%         27990.000
# max      12345678.000
# Name: price, dtype: str

# %%
def calculate_outliers(data):
    q25 = data.quantile(0.25)
    q75 = data.quantile(0.75)
    iqr = q75 - q25

    boundaries = (q75 - 1.5 * iqr, (q75 + 1.5 * iqr))
    return boundaries

boundaries = calculate_outliers(df.price)

boundaries
# Out:
# (np.float64(-2295.0), np.float64(58275.0))

# %%
is_outlier = (df.price < boundaries[0]) | (df.price > boundaries[1])

is_outlier.sum()
# Out:
# np.int64(207)

# %%
outliers_df = df[(df.price < boundaries[0]) | (df.price > boundaries[1])]
outliers_sorted = outliers_df.sort_values(by='price')
outliers_sorted
# Out:
#               id                                                url  \
# 934   7312212565  https://lasvegas.craigslist.org/cto/d/fresno-d...
# 4783  7308933629  https://omaha.craigslist.org/cto/d/cortland-20...
# 5977  7310551940  https://cincinnati.craigslist.org/ctd/d/camp-d...
# 8050  7307146509  https://lubbock.craigslist.org/ctd/d/brownfiel...
# 4265  7313452917  https://austin.craigslist.org/ctd/d/salem-2016...
# ...          ...                                                ...
# 6035  7315323093  https://daytona.craigslist.org/ctd/d/orlando-2...
# 290   7310897583  https://tucson.craigslist.org/ctd/d/tucson-201...
# 5585  7313998757  https://winchester.craigslist.org/ctd/d/manass...
# 9663  7305237859  https://delaware.craigslist.org/cto/d/delaware...
# 6239  7302112231  https://akroncanton.craigslist.org/ctd/d/canto...
#
#                       region                          region_url     price  \
# ...

# %%
outliers_sorted.tail(15)
# Out:
#               id                                                url  \
# 4073  7311841843  https://albuquerque.craigslist.org/ctd/d/albuq...
# 9072  7308732637  https://evansville.craigslist.org/ctd/d/evansv...
# 1674  7303398175  https://pullman.craigslist.org/cto/d/pullman-6...
# 2963  7308463617  https://jacksonville.craigslist.org/cto/d/pont...
# 5076  7314445453  https://boston.craigslist.org/gbs/ctd/d/methue...
# 6471  7312384300  https://orlando.craigslist.org/ctd/d/orlando-2...
# 8904  7314817013  https://sandiego.craigslist.org/csd/ctd/d/dall...
# 4183  7316319465  https://portland.craigslist.org/clc/ctd/d/glad...
# 8720  7313664504  https://austin.craigslist.org/cto/d/austin-sup...
# 9042  7306718413  https://desmoines.craigslist.org/ctd/d/portlan...
# 6035  7315323093  https://daytona.craigslist.org/ctd/d/orlando-2...
# 290   7310897583  https://tucson.craigslist.org/ctd/d/tucson-201...
# 5585  7313998757  https://winchester.craigslist.org/ctd/d/manass...
# ...

# %%
df_new = df[~is_outlier]
df_new.head()
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7316474668  https://newyork.craigslist.org/lgi/cto/d/baldw...
#
#           region                           region_url  price  year  \
# 0    chattanooga   https://chattanooga.craigslist.org  54990  2020
# 1   north jersey     https://newjersey.craigslist.org  16942  2016
# 2   reno / tahoe          https://reno.craigslist.org  35590  2017
# 3   fayetteville  https://fayetteville.craigslist.org  14500  2013
# 4  new york city       https://newyork.craigslist.org  21800  2021
#
#   manufacturer                   model    fuel  odometer title_status  \
# 0          ram  2500 crew cab big horn  diesel     27442        clean
# ...

# %%
stats = df_new.groupby('year')['price'].mean().reset_index()

stats.columns = ['year', 'avg_price']
stats
# Out:
#     year     avg_price
# 0   1995  13219.472554
# 1   1996   9362.960000
# 2   1997   6441.250000
# 3   1998   6528.672727
# 4   1999   7446.641975
# 5   2000   7614.410256
# 6   2001   7852.090164
# 7   2002   7173.798658
# 8   2003   7767.962162
# 9   2004   7684.105769
# 10  2005   8019.770428
# 11  2006   8733.512195
# 12  2007   8578.738462
# 13  2008   9508.803063
# 14  2009   9703.035336
# 15  2010  11251.862857
# 16  2011  13014.494670
# 17  2012  14906.807432
# 18  2013  16138.114370
# 19  2014  18984.084375
# 20  2015  22383.042618
# 21  2016  23163.207521
# 22  2017  26328.875959
# 23  2018  28406.824289
# 24  2019  31434.111111
# 25  2020  33791.940104
# 26  2021  23868.250000
# 27  2022  15249.000000

# %%
plt.figure()
plt.scatter(df_new.year, df_new.price, alpha=0.3)

plt.title('Relationship Between Car Price and Production Year')
plt.xlabel('Production Year')
plt.ylabel('Price (USD)')

plt.show();

# %%
year_counts = df_new.groupby('year').size().reset_index()
year_counts.columns = ['year', 'car_count']
year_counts
# Out:
#     year  car_count
# 0   1995        419
# 1   1996         25
# 2   1997         44
# 3   1998         55
# 4   1999         81
# 5   2000         78
# 6   2001        122
# 7   2002        149
# 8   2003        185
# 9   2004        208
# 10  2005        257
# 11  2006        287
# 12  2007        390
# 13  2008        457
# 14  2009        283
# 15  2010        350
# 16  2011        469
# 17  2012        592
# 18  2013        682
# 19  2014        640
# 20  2015        657
# 21  2016        718
# 22  2017        782
# 23  2018        774
# 24  2019        531
# 25  2020        384
# 26  2021         40
# 27  2022          2

# %%
# Ваш код здесь
df_new = df_new[df_new.year <= 2021]
df_new.head()
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7316474668  https://newyork.craigslist.org/lgi/cto/d/baldw...
#
#           region                           region_url  price  year  \
# 0    chattanooga   https://chattanooga.craigslist.org  54990  2020
# 1   north jersey     https://newjersey.craigslist.org  16942  2016
# 2   reno / tahoe          https://reno.craigslist.org  35590  2017
# 3   fayetteville  https://fayetteville.craigslist.org  14500  2013
# 4  new york city       https://newyork.craigslist.org  21800  2021
#
#   manufacturer                   model    fuel  odometer title_status  \
# 0          ram  2500 crew cab big horn  diesel     27442        clean
# ...

# %%
stats_by = df_new.groupby('year')['price'].mean().reset_index()

stats_by.columns = ['year', 'avg_price']

stats_by.head()
# Out:
#    year     avg_price
# 0  1995  13219.472554
# 1  1996   9362.960000
# 2  1997   6441.250000
# 3  1998   6528.672727
# 4  1999   7446.641975

# %%
plt.figure()

plt.plot(stats_by['year'],
         stats_by['avg_price'],
         color='blue',
         marker='D',
         markerfacecolor='orange')

plt.title('Average Car Price Trend by Production Year')
plt.xlabel('Production Year')
plt.ylabel('Average Price (USD)')

plt.show()

# %%
correlation = df_new.year.corr(df_new.price)
print(f"Pearson correlation coefficient: {round(correlation, 3)}")
# Out:
# Pearson correlation coefficient: 0.55

# %%
plt.figure(figsize=(8, 5))

plt.hist(df_new['price'], bins=20, color='indigo')
plt.title('Car Price Distribution')
plt.xlabel('Price (USD)')
plt.ylabel('Number of Cars')
plt.show()

# %%
df_new.to_csv('data/vehicles_dataset_upd2.csv', index=False)

# %%
plt.figure(figsize=(12, 8))

colors = {'low': 'green', 'medium': 'orange', 'high': 'red'}

for price_category in colors:
    color = colors[price_category]
    data = df_new[df_new['price_category'] == price_category]
    plt.hist(data['price'], bins=20, color=color, alpha=0.7, label=price_category)

plt.title('Car Price Distribution by Price Categories')
plt.xlabel('Price (USD)')
plt.ylabel('Number of Cars')
plt.legend(title='Price Category')
plt.show()

# %%
plt.figure(figsize=(12, 8))

colors = {'low': 'green', 'medium': 'orange', 'high': 'red'}

for price_category in  colors:
    color = colors[price_category]
    data = df_new[df_new['price_category'] == price_category]
    plt.scatter(data['year'], data['price'],
                color=color,
                label=price_category)

plt.title('Relationship Between Price and Production Year by Price Categories')
plt.xlabel('Production Year')
plt.ylabel('Price (USD)')
plt.legend(title='Price Category', loc='lower right')
plt.show()

# %%
stats = df_new.groupby('manufacturer').size().reset_index()

stats.columns = ['manufacturer', 'car_count']
stats
# Out:
#        manufacturer  car_count
# 0             acura        149
# 1        alfa-romeo         13
# 2              audi        193
# 3               bmw        307
# 4             buick        145
# 5          cadillac        179
# 6         chevrolet       1243
# 7          chrysler        159
# 8            datsun          2
# 9             dodge        321
# 10          ferrari          1
# 11             fiat         23
# 12             ford       1564
# 13              gmc        343
# 14  harley-davidson          4
# 15            honda        460
# 16          hyundai        221
# 17         infiniti        117
# 18           jaguar         43
# 19             jeep        483
# 20              kia        198
# 21            lexus        175
# 22          lincoln        109
# 23            mazda        142
# 24    mercedes-benz        221
# 25          mercury         32
# 26             mini         69
# 27       mitsubishi         81
# 28           nissan        452
# ...

# %%
plt.figure(figsize=(20, 10))

plt.bar(stats['manufacturer'], stats['car_count'], width=0.9, color=['springgreen','dodgerblue'])
plt.title('Number of Cars by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Number of Cars')

plt.xticks(rotation=45)
plt.show()

# %%
# Ваш код здесь
stats = df_new.groupby('transmission').size().reset_index()

stats.columns = ['transmission_type', 'car_count']
stats
# Out:
#   transmission_type  car_count
# 0         automatic       7398
# 1            manual        612
# 2             other       1649

# %%
# Ваш код здесь
plt.figure(figsize=(12, 8))

plt.pie(stats['car_count'], labels=stats['transmission_type'],
        autopct='%1.0f%%', labeldistance=None,
        colors=['dodgerblue', 'green', 'orange'])
plt.title('Transmission Types Distribution in Dataset')
plt.legend()
plt.show()
